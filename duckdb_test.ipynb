# %%
import duckdb as db
import pandas as pd
import numpy as np

# %%
db.sql('SELECT 1').show()
# Out:
# ┌───────┐
# │   1   │
# │ int32 │
# ├───────┤
# │     1 │
# └───────┘

# %%
df = db.sql('SELECT 23').df()
df.head()
# Out:
#    23
# 0  23
