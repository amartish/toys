# %%
print('hello world')
# Out:
# hello world

# %%
'''

I would like to create a notebook to determine the "hottest" men's
 college basketball players going into the march madness tournament.  
 The definition of "hottest" is: they are trending toward scoring more points 
 recently and they are likely to score a lot of points in their next few games. 
   Sketch me an outline of how you would put this together for me.

'''
